# %% [markdown]
# ### Given the following dataset, containing information about a year's worth of weather.
# - Using this data, calculate the percent of time it was raining each month.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("weather_2012.csv")

# %%
data
# Out:
#                 Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 0     2012-01-01 00:00:00      -1.8                -3.9           86
# 1     2012-01-01 01:00:00      -1.8                -3.7           87
# 2     2012-01-01 02:00:00      -1.8                -3.4           89
# 3     2012-01-01 03:00:00      -1.5                -3.2           88
# 4     2012-01-01 04:00:00      -1.5                -3.3           88
# ...                   ...       ...                 ...          ...
# 8779  2012-12-31 19:00:00       0.1                -2.7           81
# 8780  2012-12-31 20:00:00       0.2                -2.4           83
# 8781  2012-12-31 21:00:00      -0.5                -1.5           93
# 8782  2012-12-31 22:00:00      -0.2                -1.8           89
# 8783  2012-12-31 23:00:00       0.0                -2.1           86
#
#       Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)               Weather
# ...

# %%
month_list = []

# %%
for index, row in data.iterrows(): 
    date_i = row["Date/Time"]
    month = date_i.split("-")[1]
    month_list.append(month)

# %%
data['Month'] = month_list
data
# Out:
#                 Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 0     2012-01-01 00:00:00      -1.8                -3.9           86
# 1     2012-01-01 01:00:00      -1.8                -3.7           87
# 2     2012-01-01 02:00:00      -1.8                -3.4           89
# 3     2012-01-01 03:00:00      -1.5                -3.2           88
# 4     2012-01-01 04:00:00      -1.5                -3.3           88
# ...                   ...       ...                 ...          ...
# 8779  2012-12-31 19:00:00       0.1                -2.7           81
# 8780  2012-12-31 20:00:00       0.2                -2.4           83
# 8781  2012-12-31 21:00:00      -0.5                -1.5           93
# 8782  2012-12-31 22:00:00      -0.2                -1.8           89
# 8783  2012-12-31 23:00:00       0.0                -2.1           86
#
#       Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)               Weather  \
# ...

# %%
data_by_month = data.groupby('Month')

# %%
len(data_by_month)
# Out:
# 12

# %%
rain_percentage = {}
number_days_rain = []
for i, k in data_by_month: 
    print(i, k)
    
    for index, row in k.iterrows(): 
        weather = row["Weather"]
        if "Rain" in weather:
            number_days_rain.append("Rain")
    rain_percentage[i]= (len(number_days_rain) / len(k)) * 100
    number_days_rain = []
# Out:
# 01                Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 0    2012-01-01 00:00:00      -1.8                -3.9           86
# 1    2012-01-01 01:00:00      -1.8                -3.7           87
# 2    2012-01-01 02:00:00      -1.8                -3.4           89
# 3    2012-01-01 03:00:00      -1.5                -3.2           88
# 4    2012-01-01 04:00:00      -1.5                -3.3           88
# ..                   ...       ...                 ...          ...
# 739  2012-01-31 19:00:00      -7.7               -10.9           78
# 740  2012-01-31 20:00:00      -7.4               -10.7           77
# 741  2012-01-31 21:00:00      -7.1               -10.5           77
# 742  2012-01-31 22:00:00      -7.1               -10.4           77
# 743  2012-01-31 23:00:00      -6.8                -9.9           79
#
#      Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)                Weather  \
# ...

# %%
rain_percentage
# Out:
# {'01': 3.8978494623655915,
#  '02': 4.597701149425287,
#  '03': 6.182795698924731,
#  '04': 13.055555555555557,
#  '05': 10.349462365591398,
#  '06': 10.694444444444445,
#  '07': 3.6290322580645165,
#  '08': 5.64516129032258,
#  '09': 7.916666666666666,
#  '10': 11.693548387096774,
#  '11': 6.805555555555555,
#  '12': 9.67741935483871}
